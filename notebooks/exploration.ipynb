# %%
import pandas as pd

demo = pd.read_stata("../data/raw/demo.dta")

demo.head()
# Out:
#       mmid            name          city      zip       lat      long  \
# 0      NaN                                    NaN       NaN       NaN
# 1  16892.0  DOMINICKS    2  RIVER FOREST  60305.0  419081.0  878131.0
# 2  16893.0  DOMINICKS    4    PARK RIDGE  60068.0  420392.0  878425.0
# 3  16894.0  DOMINICKS    5      PALATINE  60067.0  421203.0  880431.0
# 4  16895.0  DOMINICKS    8      OAK LAWN  60453.0  417331.0  877436.0
#
#    weekvol  store scluster  zone  ...   cpwvol4   cpwvol5  farthest    dtdist  \
# 0      NaN    NaN            NaN  ...       NaN       NaN        10       NaN
# 1    350.0    2.0        C   1.0  ...  0.236891  0.376927         4  1.702432
# 2    300.0    4.0        A   2.0  ...  0.743272  0.772489         7  1.367609
# 3    550.0    5.0        D   2.0  ...  0.621281  0.736307         4  1.201112
# 4    600.0    8.0        C   5.0  ...  0.660947  0.641016         2  2.316148
#
#       dtvol    dtwvol  dtcomp  priclow  pricmed  prichigh
# ...

# %%
demo.columns
# Out:
# Index(['mmid', 'name', 'city', 'zip', 'lat', 'long', 'weekvol', 'store',
#        'scluster', 'zone',
#        ...
#        'cpwvol4', 'cpwvol5', 'farthest', 'dtdist', 'dtvol', 'dtwvol', 'dtcomp',
#        'priclow', 'pricmed', 'prichigh'],
#       dtype='str', length=510)

# %%
keywords = ["income", "educ", "age", "house", "hsize", "retired", "unemp", "density", "ethnic"]

for col in demo.columns:
    if any(k in col.lower() for k in keywords):
        print(col)
# Out:
# age9
# age60
# ethnic
# educ
# income
# hsizeavg
# hsize1
# hsize2
# hsize34
# hsize567
# sinhouse
# density
# retired
# unemp
# mortgage
